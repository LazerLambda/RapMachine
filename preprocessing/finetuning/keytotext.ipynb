# %%
# !pip install keytotext
# !pip install transformers
# !pip install torchmetrics==0.6
# !pip install folium==0.2.1
# !pip install torch
# Out:
# ...
#      |████████████████████████████████| 311 kB 31.3 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 68.3 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 63.4 MB/s
# ...
#      |████████████████████████████████| 527 kB 71.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 56.8 MB/s
# ...
#      |████████████████████████████████| 133 kB 68.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 55.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 75.2 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 58.3 MB/s
# ...
#      |████████████████████████████████| 144 kB 54.4 MB/s
# ...
#      |████████████████████████████████| 396 kB 50.8 MB/s
# ...
#      |████████████████████████████████| 952 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 829 kB 71.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.2 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 52.7 MB/s
# ...

# %%
from keytotext import trainer, make_dataset
import pandas as pd

from sklearn.model_selection import train_test_split
# Out:
# Global seed set to 42

# %%
IN_COLAB: bool = False
try:
  from google.colab import drive, files
  IN_COLAB = True
except:
  IN_COLAB = False

path: str = ''
if IN_COLAB:
  drive.mount('/content/drive')
  path = 'drive/MyDrive/RapMachine/keywords.json'
  # path = 'drive/MyDrive/RapMachine/KeywordLyrics.json'
else:
  path = None

df = pd.read_json(path)
df = df.rename(columns={'Text': 'text', 'Keywords': 'keywords'})
# Out:
# Mounted at /content/drive

# %%
to_drop: list = df[list(map(lambda e: type(e) != list, df['keywords'].tolist()))].index
df = df.drop(to_drop)
df = df.dropna()

# %%
a = list(map(lambda e: len(e), df['text'].tolist()))

# %%
df['n'] = df['text'].apply(lambda x: len(x))

# %%
df = df[(df['n'] > 500) & (df['n'] < 5000)]

# %%
train_df, test_df = train_test_split(df,test_size=0.15)

# %%
model = trainer()
model.from_pretrained(model_name='t5-small')
model.train(
    train_df=train_df,
    test_df=test_df,
    batch_size=2,
    max_epochs=1,
    use_gpu=True
)
model.save_model("drive/MyDrive/RapMachine/T5-2")
# Out:
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=5)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
import torch

# %%
model

# %%
def predict(
        keywords: list,
        max_length: int = 512,
        min_length: int = 300,
        num_return_sequences: int = 1,
        num_beams: int = 2,
        top_k: int = 50,
        top_p: float = 0.95,
        do_sample: bool = True,
        repetition_penalty: float = 2.5,
        length_penalty: float = 1.0,
        early_stopping: bool = True,
        skip_special_tokens: bool = True,
        clean_up_tokenization_spaces: bool = True,
        use_gpu: bool = True,
    ):
        """
        generates prediction for K2T model
        Args:
            Keywords (list): any keywords for generating predictions
            max_length (int, optional): max token length of prediction. Defaults to 512.
            num_return_sequences (int, optional): number of predictions to be returned. Defaults to 1.
            num_beams (int, optional): number of beams. Defaults to 2.
            top_k (int, optional): Defaults to 50.
            top_p (float, optional): Defaults to 0.95.
            do_sample (bool, optional): Defaults to True.
            repetition_penalty (float, optional): Defaults to 2.5.
            length_penalty (float, optional): Defaults to 1.0.
            early_stopping (bool, optional): Defaults to True.
            skip_special_tokens (bool, optional): Defaults to True.
            clean_up_tokenization_spaces (bool, optional): Defaults to True.
            use_gpu: Defaults to True.
        Returns:
            str: returns predictions
        """
        if use_gpu:
            if torch.cuda.is_available():
                device = torch.device("cuda")
            else:
                raise Exception(
                    "exception ---> no gpu found. set use_gpu=False, to use CPU"
                )
        else:
            device = torch.device("cpu")

        source_text = " ".join(map(str, keywords))

        input_ids = model.tokenizer.encode(
            source_text, return_tensors="pt", add_special_tokens=True
        )

        # input_ids = input_ids.to(device)
        generated_ids = model.model.generate(
            input_ids=input_ids,
            num_beams=num_beams,
            max_length=max_length,
            min_length=min_length,
            repetition_penalty=repetition_penalty,
            length_penalty=length_penalty,
            early_stopping=early_stopping,
            top_p=top_p,
            top_k=top_k,
            num_return_sequences=num_return_sequences,
        )
        preds = [
            model.tokenizer.decode(
                g,
                skip_special_tokens=skip_special_tokens,
                clean_up_tokenization_spaces=clean_up_tokenization_spaces,
            )
            for g in generated_ids
        ]
        return preds[0]

# %%
predict(keywords=['compton', 'chicago', 'gangster', 'gun'], num_return_sequences=2)
# Out:
# "I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' come to the top of the list, it's all about Then that's why I'm in this bitch with my gangster gun And I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin'' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know what I'm sayin' I'm gon' go to the top, and you know
# ...

# %%
model.save_model("drive/MyDrive/RapMachine/T5-1")
